# %% [markdown]
# This notebook is written to prototype a conversion from the "ACAPS" humdata.org database into the epidemicforecasting.org format.
#
# For anything that is in the source ACAPS that we'd _like_ to be in target EF, we'll write a function to convert it.
#
# This includes data that EF already has, so that we can fill in any gaps.

# %%
import pandas as pd
import re

# %%
source_data = pd.read_csv("../../../data/epidemicforecasting/20200326-acaps-covid-19-goverment-measures-dataset-v2.xlsx - Database.csv")

# %%
source_data.sample(5)
# Out:
#         ID      COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE       REGION  \
# 2225  2408        Spain  ESP              NaN    NaN       Europe
# 440   1034     Cameroon  CMR              NaN    NaN       Africa
# 1173  2016       Israel  ISR              NaN    NaN  Middle East
# 1695   855  New Zealand  NZL              NaN    NaN      Pacific
# 1823    89       Panama  PAN              NaN    NaN     Americas
#
#                     CATEGORY                                 MEASURE  \
# 2225  Public health measures  Strengthening the public health system
# 440    Movement restrictions                                 Curfews
# 1173  Public health measures                     Awareness campaigns
# 1695  Public health measures     Introduction of quarantine policies
# 1823       Social distancing                        Schools closure
#
#      TARGETED_POP_GROUP                                           COMMENTS  \
# 2225                 No  Retired health professionals and medical stude...
# 440                  No            Curfew on bars and restaurant from 6pm.
# 1173                Yes  The Ministry of Health has contacted mobile ph...
# 1695                Yes  All returning residents and citizens must isol...
# 1823                 No                                                NaN
#
#       NON_COMPLIANCE DATE_IMPLEMENTED                                SOURCE  \
# 2225  Not applicable       15/03/2020                            Government
# 440              NaN       18/03/2020            Health Ministry — Cameroon
# 1173  Not applicable       03/02/2020                                   MoH
# 1695             NaN       20/03/2020                        Immigration NZ
# 1823  Not applicable       13/03/2020  Ministry of Foreign Affairs - France
#
#      SOURCE_TYPE                                               LINK  \
# 2225  Government  https://www.mscbs.gob.es/gabinete/notasPrensa....
# 440   Government  https://www.minsante.cm/site/?q=fr/content/dos...
# 1173  Government  https://www.gov.il/en/departments/news/08022020_1
# 1695  Government  https://www.immigration.govt.nz/about-us/covid...
# 1823  Government  https://www.diplomatie.gouv.fr/fr/conseils-aux...
#
#       ENTRY_DATE Alternative source
# 2225  26/03/2020                NaN
# 440   20/03/2020                NaN
# 1173  24/03/2020                NaN
# 1695  20/03/2020                NaN
# 1823  14/03/2020                NaN

# %% [markdown]
# Now let's see what the target data source looks like.

# %%
ef_cm = pd.read_csv(
    "../../../data/epidemicforecasting/epimodel-covid-data/sources/COVID 19 Containment measures data.csv",
    parse_dates=['Date Start','Date end intended']).dropna(subset=['Country'])

# %%
ef_cm.sample(5)
# Out:
#        ID Applies To           Country Date Start Date end intended  \
# 1546  NaN        NaN  US: Pennsylvania 2020-03-22               NaT
# 719   702        NaN             Italy 2020-02-23               NaT
# 743   NaN    Bavaria           Germany 2020-02-28               NaT
# 606   586        NaN            Russia 2020-03-20               NaT
# 57    145        NaN         Singapore 2020-02-07               NaT
#
#                      Description of measure implemented Exceptions  \
# 1546  On March 22, Philadelphia Mayor Jim Kenney iss...        NaN
# 719   Trenitalia and Italo, the major providers for ...        NaN
# 743   Train railway companies must report passengers...        NaN
# 606   Russia will limit flights to the United States...        NaN
# 57              Contagion threat level raised to Orange        NaN
#
#      Implementing City Implementing State/Province  \
# 1546      Philadelphia                         NaN
# 719                NaN                         NaN
# 743                NaN                         NaN
# 606                NaN                         NaN
# 57                 NaN                         NaN
#
#                                        Keywords  Quantity  \
# 1546            cluster isolation - no symptoms       1.0
# 719   public hygiene, public transport cleaning       NaN
# 743                domestic traveller screening       NaN
# 606   international travel ban - risk countries       NaN
# 57                          public announcement       NaN
#
#                                                  Source Target city  \
# 1546                                                NaN         NaN
# 719   https://en.wikipedia.org/wiki/2020_coronavirus...         NaN
# 743   https://www.reuters.com/article/us-china-healt...         NaN
# 606   https://www.themoscowtimes.com/2020/03/18/coro...         NaN
# 57    https://www.straitstimes.com/singapore/coronav...         NaN
#
#                                          Target country Target region  \
# 1546                                                NaN           NaN
# 719                                                 NaN           NaN
# 743                                                 NaN           NaN
# 606   The United Kingdom, United Arab Emirates, Unit...           NaN
# 57                                                  NaN           NaN
#
#       Target state
# 1546           NaN
# 719            NaN
# 743            NaN
# 606            NaN
# 57             NaN

# %% [markdown]
# OK great. So what if we picked one category where `ACAPS` was useful, wrote a mapping from that category to one in `ef_cm`, converted it to `ef_cm` format, and then imported it into the dataset itself?

# %% [markdown]
# ## Explore ACAPS categories

# %% [markdown]
# ACAPS follow a rough hierarchy of "category" and "measure".

# %% [markdown]
# First, the data needs a bit of tidying up - let's trim whitespace out of the relevant columns.

# %%
source_data.CATEGORY = source_data.CATEGORY.str.strip()
source_data.MEASURE = source_data.MEASURE.str.strip()
#and because we want source_data without a sublocale to merge we're going to change NaN to a ''.
#need to change NA to a zero-length string so that it'll list as a unique item.
source_data.loc[:,"ADMIN_LEVEL_NAME_MERGEABLE"]=source_data.ADMIN_LEVEL_NAME
source_data.loc[pd.isnull(source_data.ADMIN_LEVEL_NAME),"ADMIN_LEVEL_NAME_MERGEABLE"]=''

# %% [markdown]
# Here's list of each CATEGORY with all of the MEASURE items in each category.

# %%
for c in source_data.CATEGORY.unique():
    print(c)
    print(source_data.loc[source_data.CATEGORY==c,'MEASURE'].unique())
    print("\n")
# Out:
# Public health measures
# ['Health screenings in airports and border crossings'
#  'Introduction of quarantine policies' 'Awareness campaigns'
#  'Strengthening the public health system' 'General recommendations'
#  'Testing policy' 'Psychological assistance and medical social work'
#  'Mass population testing' 'Amendments to funeral and burial regulations'
#  'Obligatory medical tests not related to COVID-19']
#
#
# Social and economic measures
# ['Emergency administrative structures activated or established'
#  'Limit product imports/exports' 'Economic measures' 'Schools closure'
#  'State of emergency declared' 'Military deployment']
#
#
# Social distancing
# ['Limit public gatherings' 'Schools closure' 'Public services closure'
#  'Changes in prison-related policies'
#  'Introduction of quarantine policies' 'Border checks']
#
#
# Movement restrictions
# ['Border closure' 'Border checks' 'International flights suspension'
#  'Domestic travel restrictions' 'Checkpoints within the country' 'Curfews'
#  'Visa restrictions' 'Surveillance and monitoring'
#  'Additional health/documents requirements upon arrival'
#  'Lockdown of refugee/idp camps or other minorities'
#  'Complete border closure']
#
#
# Lockdown
# ['Partial lockdown' 'Full lockdown']
#
#
# Social Distancing
# ['Limit public gatherings']
#
#
# Social and Economic Measures
# ['Emergency administrative structures activated or established'
#  'Economic measures']
#
#
# #REF!
# ['State of emergency declared' 'Schools closure' 'Limit public gatherings']
#
#
# Movement Restrictions
# ['Border closure']

# %% [markdown]
# Lockdown is a good one to start with. `ef` coverage is likely to be quite good, which makes it a useful test case. Let's try importing those.

# %% [markdown]
# ## Importing single category from ACAPS to ef format

# %%
source_data.loc[(source_data.CATEGORY=="Lockdown") & (source_data.MEASURE=="Full lockdown"),]
# Out:
#         ID       COUNTRY  ISO ADMIN_LEVEL_NAME  PCODE  REGION  CATEGORY  \
# 1207  1677         Italy  ITA              NaN    NaN  Europe  Lockdown
# 1218  1688         Italy  ITA              NaN    NaN  Europe  Lockdown
# 1903  2190   Philippines  PHL              NaN    NaN    Asia  Lockdown
# 2193  1844  South Africa  ZAF              NaN    NaN  Africa  Lockdown
# 2211   707         Spain  ESP   Basque Country    NaN  Europe  Lockdown
# 2307  2390   Switzerland  CHE           Ticino    NaN  Europe  Lockdown
#
#             MEASURE TARGETED_POP_GROUP  \
# 1207  Full lockdown                 No
# 1218  Full lockdown                Yes
# 1903  Full lockdown                 No
# 2193  Full lockdown                 No
# 2211  Full lockdown                Yes
# 2307  Full lockdown                 No
#
#                                                COMMENTS   NON_COMPLIANCE  \
# 1207  All production will be closed and strictly onl...  Up to detention
# 1218  All regions at risk (specifically defined) nee...  Up to detention
# 1903  Full lock-down of the multiple regions with on...    Not available
# 2193  All of South Africa will go into total lockdow...              NaN
# 2211                                      Some villages              NaN
# 2307  The closure of all non-essential work, includi...    Not available
#
#      DATE_IMPLEMENTED                                SOURCE SOURCE_TYPE  \
# 1207       23/03/2020              Ministry of the Interior  Government
# 1218       23/02/2020                            Government  Government
# 1903       26/03/2020                Philippine News Agency  Government
# 2193       27/03/2020            President press conference  Government
# 2211       13/03/2020  Ministry of Foreign Affairs - France  Government
# 2307       23/03/2020                             SwissInfo       Media
#
#                                                    LINK  ENTRY_DATE  \
# 1207  https://www.interno.gov.it/it/notizie/emergenz...  23/03/2020
# 1218  https://www.normattiva.it/uri-res/N2Ls?urn:nir...  23/03/2020
# 1903            https://www.pna.gov.ph/articles/1097781  25/03/2020
# 2193        https://www.youtube.com/watch?v=H94eg5gEDeE  23/03/2020
# 2211  https://www.diplomatie.gouv.fr/fr/conseils-aux...  16/03/2020
# 2307  https://www.swissinfo.ch/eng/coronavirus-fallo...  26/03/2020
#
#                                      Alternative source  \
# 1207  http://www.salute.gov.it/portale/nuovocoronavi...
# 1218                                                NaN
# 1903  https://www.pna.gov.ph/articles/1097654 AND ht...
# 2193  https://twitter.com/GovernmentZA?ref_src=twsrc...
# 2211                                                NaN
# 2307                                                NaN
#
#      ADMIN_LEVEL_NAME_MERGEABLE
# 1207
# 1218
# 1903
# 2193
# 2211             Basque Country
# 2307                     Ticino

# %%
source_data.columns
# Out:
# Index(['ID', 'COUNTRY', 'ISO', 'ADMIN_LEVEL_NAME', 'PCODE', 'REGION',
#        'CATEGORY', 'MEASURE', 'TARGETED_POP_GROUP', 'COMMENTS',
#        'NON_COMPLIANCE', 'DATE_IMPLEMENTED', 'SOURCE', 'SOURCE_TYPE', 'LINK',
#        'ENTRY_DATE', 'Alternative source', 'ADMIN_LEVEL_NAME_MERGEABLE'],
#       dtype='object')

# %%
ef_cm.columns
# Out:
# Index(['ID', 'Applies To', 'Country', 'Date Start', 'Date end intended',
#        'Description of measure implemented', 'Exceptions', 'Implementing City',
#        'Implementing State/Province', 'Keywords', 'Quantity', 'Source',
#        'Target city', 'Target country', 'Target region', 'Target state'],
#       dtype='object')

# %% [markdown]
# We'll need to map country names. If we assume each source has consistent country names then we can create a mapping CSV that records the names. I'll do this in a Gsheet and then save to CSV.

# %% [markdown]
# ## Sort out country names

# %%
pd.DataFrame(ef_cm.Country.unique()).to_csv("../../../data/epidemicforecasting/ef_countryname_lexicon.csv")


#https://stackoverflow.com/questions/35268817/unique-combinations-of-values-in-selected-columns-in-pandas-data-frame-and-count
grouping_cols = ["COUNTRY","ISO","ADMIN_LEVEL_NAME_MERGEABLE"]
source_data_grouped = pd.DataFrame(source_data.loc[:,grouping_cols]).groupby(grouping_cols).size().reset_index().rename(columns={0:'count'})
print(source_data_grouped.sample(5))
source_data_grouped.to_csv("../../../data/epidemicforecasting/acaps_countryname_lexicon.csv")
# Out:
#          COUNTRY  ISO ADMIN_LEVEL_NAME_MERGEABLE  count
# 1    Afghanistan  AFG                      Herat      2
# 213  Saint Lucia  LCA                                 2
# 211       Rwanda  RWA                                19
# 268        Yemen  YEM                                 4
# 202  Philippines  PHL                  Sorsogon       1

# %%
region_lexicon_conversion = pd.read_csv("../../../data/epidemicforecasting/epimodel-covid-data/dataimport/ef_region_lexicon_conversion.csv")

# %%
region_lexicon_conversion.sample(5)
# Out:
#     EF_LOCALE EF_SUBLOCALE ACAPS_COUNTRY ACAPS_ISO ACAPS_ADMIN_LEVEL_NAME  \
# 263  Thailand          NaN      Thailand       THA                    NaN
# 228       NaN          NaN  Saudi Arabia       SAU                    NaN
# 92        NaN          NaN      Ethiopia       ETH            Addis Ababa
# 262       NaN          NaN      Tanzania       TZA                    NaN
# 310       NaN          NaN         Yemen       YEM                    NaN
#
#     Notes
# 263   NaN
# 228   NaN
# 92    NaN
# 262   NaN
# 310   NaN

# %% [markdown]
# ## create a function that can get ef formatted data from ACAPS

# %%
source_data.efc_Keywords=""

# %%
def from_acaps_to_ef_lockdown(source_rows):
    #let's start with only handling lockdown rows; we can expand applicability from there.
    #the source data has country and ISO information for country.
    #and for now, let's start with handling only top-level ACAPS data
    #it does do regional-level breakdowns for many countries
    #that's good data to use.
    
    #OK, great, so now we have merged in the region lexicon.
    acaps_region_grouping_cols =["COUNTRY","ISO","ADMIN_LEVEL_NAME_MERGEABLE"]
    region_lexicon_conversion.loc[pd.isnull(region_lexicon_conversion.ACAPS_ADMIN_LEVEL_NAME),"ACAPS_ADMIN_LEVEL_NAME"]=''

    source_data.merge(region_lexicon_conversion,
                      left_on=acaps_region_grouping_cols,
                      right_on=["ACAPS_COUNTRY","ACAPS_ISO","ACAPS_ADMIN_LEVEL_NAME"]
                     )

    source_data["efc_Keywords"]=''


    #identify rows to work with for this particular category
    append_rows = (
        (source_data.CATEGORY=="Lockdown")
        # & (source_data.MEASURE=="Full lockdown")
    )

    #if there is no data in the keyword list, just set the list to contain the new keyword
    #if there is data, then append.
    append_rows_nonempty = (append_rows & (source_data.efc_Keywords.str.len()>0))
    source_data.loc[append_rows_nonempty,
                   "efc_Keywords"] = (
        [', '.join([kl, 'blanket curfew - no symptoms']) for kl in source_data.efc_Keywords[append_rows_nonempty]]
    )

    #items that we can transfer over generally.
    source_data.loc[append_rows & (source_data.efc_Keywords.str.len()==0),
                   "efc_Keywords"] = 'blanket curfew - no symptoms'


    source_data['efc_Date Start'] = source_data['DATE_IMPLEMENTED']
    source_data['efc_Description of measure implemented'] = source_data["COMMENTS"]

    #we could fill in state/province whereever the source data has an ADMIN_LEVEL_NAME
    source_data['efc_Implementing State/Province'] = source_data["ADMIN_LEVEL_NAME"]

    source_data['efc_Source'] = source_data["SOURCE"] + " (" +  source_data["SOURCE_TYPE"] + ", " + source_data["LINK"] 

    #now we take all the columns that have "efc_" at the beginning in source_data, and that's our output
    efc_cols = list(filter(re.compile("^efc_").match,source_data.columns))
    #only the rows where we've identified a tab
    efc_out = source_data.loc[source_data.efc_Keywords!='',efc_cols]
    efc_out.columns = [s.replace("efc_","") for s in efc_cols]

    return(efc_out)

# %%
from_acaps_to_ef_lockdown(source_data)
# Out:
#                           Keywords  Date Start  \
# 41    blanket curfew - no symptoms  23/03/2020
# 74    blanket curfew - no symptoms  19/03/2020
# 131   blanket curfew - no symptoms  16/03/2020
# 145   blanket curfew - no symptoms  19/03/2020
# 285   blanket curfew - no symptoms  18/03/2020
# 321   blanket curfew - no symptoms  30/03/2020
# 334   blanket curfew - no symptoms  16/03/2020
# 379   blanket curfew - no symptoms  18/03/2020
# 395   blanket curfew - no symptoms  13/03/2020
# 507   blanket curfew - no symptoms         NaN
# 541   blanket curfew - no symptoms  16/03/2020
# 619   blanket curfew - no symptoms  16/03/2020
# 683   blanket curfew - no symptoms  17/03/2020
# 708   blanket curfew - no symptoms  18/03/2020
# 709   blanket curfew - no symptoms  11/03/2020
# 815   blanket curfew - no symptoms  16/03/2020
# 821   blanket curfew - no symptoms  17/03/2020
# 863   blanket curfew - no symptoms  23/03/2020
# 878   blanket curfew - no symptoms  21/03/2020
# 911   blanket curfew - no symptoms  23/03/2020
# 963   blanket curfew - no symptoms  20/03/2020
# 1016  blanket curfew - no symptoms  17/03/2020
# 1063  blanket curfew - no symptoms  16/03/2020
# 1117  blanket curfew - no symptoms  11/03/2020
# 1163  blanket curfew - no symptoms  17/03/2020
# 1189  blanket curfew - no symptoms  25/03/2020
# 1190  blanket curfew - no symptoms  19/03/2020
# 1196  blanket curfew - no symptoms  08/03/2020
# 1203  blanket curfew - no symptoms  20/03/2020
# 1207  blanket curfew - no symptoms  23/03/2020
# ...                            ...         ...
# 1242  blanket curfew - no symptoms  18/03/2020
# 1286  blanket curfew - no symptoms  22/03/2020
# 1415  blanket curfew - no symptoms  16/03/2020
# 1421  blanket curfew - no symptoms  17/03/2020
# 1469  blanket curfew - no symptoms  18/03/2020
# 1476  blanket curfew - no symptoms  18/03/2020
# 1483  blanket curfew - no symptoms  24/03/2020
# 1639  blanket curfew - no symptoms  28/03/2020
# 1640  blanket curfew - no symptoms  28/03/2020
# 1709  blanket curfew - no symptoms  23/03/2020
# 1818  blanket curfew - no symptoms  07/03/2020
# 1859  blanket curfew - no symptoms  24/03/2020
# 1881  blanket curfew - no symptoms  16/03/2020
# 1903  blanket curfew - no symptoms  26/03/2020
# 1957  blanket curfew - no symptoms  24/03/2020
# 2035  blanket curfew - no symptoms  21/03/2020
# 2046  blanket curfew - no symptoms  20/03/2020
# 2087  blanket curfew - no symptoms  25/03/2020
# 2193  blanket curfew - no symptoms  27/03/2020
# 2211  blanket curfew - no symptoms  13/03/2020
# 2215  blanket curfew - no symptoms  16/03/2020
# 2306  blanket curfew - no symptoms         NaN
# 2307  blanket curfew - no symptoms  23/03/2020
# 2308  blanket curfew - no symptoms         NaN
# 2352  blanket curfew - no symptoms  21/03/2020
# 2448  blanket curfew - no symptoms  24/03/2020
# 2480  blanket curfew - no symptoms  24/03/2020
# 2491  blanket curfew - no symptoms  22/03/2020
# 2499  blanket curfew - no symptoms  16/03/2020
# 2502  blanket curfew - no symptoms  17/03/2020
#
#                      Description of measure implemented  \
# 41    Bilda (complete confinement - all movement in ...
# 74    Until 31st of March included, travels are rest...
# 131   Citizens are suspend all non-essential activit...
# 145   All municipalities in Tyrol are under quaranti...
# 285   Police enforced general lock-down limiting the...
# 321   Towns of Cotonou, Abomey-Calavi, Allada, Ouida...
# 334   Discotheques, bars, movie theaters, sporting e...
# 379                                All cinemas closed.
# 395   School closures for one week starting Monday.\...
# 507                                     In many regions
# 541   nightly curfew as of 16 March from 7pm until 6...
# 619   Nationwide quarantine from 16 March until 24 M...
# 683    Stict confinement with a curfew from 9pm to 5am.
# 708   The President of El Salvador implemented a 48-...
# 709   The President of El Salvador declared a 30-day...
# 815        Closure of all non-essential establishments
# 821   further restrictions of movement, all people r...
# 863   quarantine order for Marneuli and Bolnisi, two...
# 878   Freiburg started, with ongoing discussions on ...
# 911   Nation wide until further notice. People are o...
# 963   Citizens must stay at home and limit movement ...
# 1016  shops and restaurants (excluding food stores a...
# 1063  closure of selected public institutions such a...
# 1117  lockdown for 7 days in Najaf governorate as of...
# 1163  mandatory lockdown: do not go outside unless a...
# 1189   further reducing entry to the public space, i...
# 1190  social distancing, leave home only for specifi...
# 1196  Northern Italian regions (NUTS2) officially lo...
# 1203  Limitations extended with public parks and pla...
# 1207  All production will be closed and strictly onl...
# ...                                                 ...
# 1242  Government imposes Defense law. All public and...
# 1286  Korean government will restrict the operation ...
# 1415        traffic is limited to essential trips only
# 1421  Leaving is allowed for essentials, to get fres...
# 1469  Movement Control Order (MCO) in place from Mar...
# 1476  From 18 - 31 March 2020, Sarawakians entering ...
# 1483  All markets, supermarkets, coffee shops and re...
# 1639                                                NaN
# 1640                                                NaN
# 1709  New Zealanders who are outside of essential se...
# 1818       Bethlehem in lockdown after cases confirmed
# 1859  14 day national lockdown starting tomorrow Mar...
# 1881  Forced quarantine, travels are regulated and l...
# 1903  Full lock-down of the multiple regions with on...
# 1957  People are not allowed to leave their home, ap...
# 2035  Announcement of lockdown for the country of Rw...
# 2046  All persons of the age of 60 and above are to ...
# 2087  lockdown in Makkah, Madinah and Riyadh – no re...
# 2193  All of South Africa will go into total lockdow...
# 2211                                      Some villages
# 2215  Movement only allowed for: travel to make esse...
# 2306  Reasons for leaving home are for groceries, he...
# 2307  The closure of all non-essential work, includi...
# 2308        People above 65 are ordered to stay at home
# 2352    Lomé, Tsévié, Kpalimé et Sokodé under lockdown.
# 2448  General lockdown in UK of immediate effect. Pe...
# 2480                  65+ are asked to remain at home.
# 2491  Aneityum Island and the small, adjoining Myste...
# 2499     Partial quarantine expanded to entire country.
# 2502  All transports are limited to the strict minim...
#
#      Implementing State/Province  \
# 41                           NaN
# 74                           NaN
# 131                          NaN
# 145                        Tyrol
# 285                          NaN
# 321                          NaN
# 334                          NaN
# 379                          NaN
# 395                          NaN
# 507                          NaN
# 541     Cordoba, Meta, Santander
# 619                          NaN
# 683                          NaN
# 708                      Metapan
# 709                          NaN
# 815                          NaN
# 821                          NaN
# 863        Marneuli and Bolnisi,
# 878                     Freiburg
# 911                          NaN
# 963                          NaN
# 1016                         NaN
# 1063                         NaN
# 1117                       Najaf
# 1163                         NaN
# 1189                         NaN
# 1190                         NaN
# 1196        Lombardia and Veneto
# 1203                         NaN
# 1207                         NaN
# ...                          ...
# 1242                         NaN
# 1286                         NaN
# 1415                         NaN
# 1421                         NaN
# 1469                         NaN
# 1476      East Malaysia: Sarawak
# 1483                     Sarawak
# 1639                      Khomas
# 1640                      Erango
# 1709                         NaN
# 1818                   Bethlehem
# 1859                         NaN
# 1881                         NaN
# 1903                         NaN
# 1957                         NaN
# 2035                         NaN
# 2046                         NaN
# 2087                         NaN
# 2193                         NaN
# 2211              Basque Country
# 2215                         NaN
# 2306                         NaN
# 2307                      Ticino
# 2308                         Uri
# 2352                         NaN
# 2448                         NaN
# 2480                         NaN
# 2491                    Aneityum
# 2499                         NaN
# 2502                         NaN
#
#                                                  Source
# 41    Gardaworld (Other organisations, https://www.g...
# 74    Ministry of Health — Argentina (Government, ht...
# 131   Ministry of Social Affairs (Government, https:...
# 145   Government (Government, https://www.tirol.gv.a...
# 285   Government (Government, https://www.belgium.be...
# 321   Government — Benin (Government, https://www.go...
# 334   US Embassy (Government, https://bo.usembassy.g...
# 379   Brunei MoH (Government, http://www.moh.gov.bn/...
# 395   Bulgarian Ntnl. Television (Media, https://www...
# 507   Ministry of health (Government, http://en.nhc....
# 541   ElTiempo (Media, https://www.eltiempo.com/colo...
# 619   U.S. Embassy in the Czech Republik (Government...
# 683   Ministry of Foreign Affairs — France (Governme...
# 708   US Embassy (Government, https://sv.usembassy.g...
# 709   GardaWorld (Other organisations, https://www.g...
# 815   U.K. Government Travel Advice (Government, htt...
# 821   Ministry of Interior (Government, https://www....
# 863   US Embassy Georgia (Government, https://ge.use...
# 878   Tagesschau (Media, https://www.tagesschau.de/i...
# 911   International SOS (Other organisations, https:...
# 963   Foreign Ministry — UK (Government, https://www...
# 1016  Official Website (Government, http://abouthung...
# 1063  Aljazeera (Media, https://www.aljazeera.com/ne...
# 1117  Garda (Other, https://www.garda.com/crisis24/n...
# 1163  MoH (Government, https://govextra.gov.il/minis...
# 1189  MoH (Government, https://www.gov.il/en/departm...
# 1190  MoH (Government, https://www.gov.il/en/departm...
# 1196  Government (Media, https://www.ilfattoquotidia...
# 1203  Ministry of Health (Government, http://www.sal...
# 1207  Ministry of the Interior (Government, https://...
# ...                                                 ...
# 1242  NRC MERO (Other organisations, Internal Docume...
# 1286  KCDC (Government, https://www.cdc.go.kr/board/...
# 1415  Government of Iceland (Government, https://gou...
# 1421  Ministry of Health (Government, https://msan.g...
# 1469  Malaysia Govt (Government, https://www.malaysi...
# 1476  International SOS (Other organisations, https:...
# 1483  The Star (Media, https://www.thestar.com.my/ne...
# 1639  Garda (Media, https://www.garda.com/crisis24/n...
# 1640  Garda (Media, https://www.garda.com/crisis24/n...
# 1709  NZ Govt (Government, https://covid19.govt.nz/g...
# 1818  Aljazeera (Media, https://www.aljazeera.com/ne...
# 1859  RNZ (Media, https://www.rnz.co.nz/news/pacific...
# 1881  Government — Peru (Government, https://www.gob...
# 1903  Philippine News Agency (Government, https://ww...
# 1957  Government (Government, https://www.gov.pl/web...
# 2035  Rwanda MoH (Government, https://www.rbc.gov.rw...
# 2046  Samoa Govt (Government, http://www.samoagovt.w...
# 2087  International SOS (Other organisations, https:...
# 2193  President press conference (Government, https:...
# 2211  Ministry of Foreign Affairs - France (Governme...
# 2215  Ministry of Foreign Affairs - France (Governme...
# 2306  Government (Government, https://www.bag.admin....
# 2307  SwissInfo (Media, https://www.swissinfo.ch/eng...
# 2308                                                NaN
# 2352  Government — Togo (Government, https://covid19...
# 2448  BBC News: prime minister press conference (Med...
# 2480  MoH (Government, https://www.gub.uy/ministerio...
# 2491  RNZ (Media, https://www.rnz.co.nz/internationa...
# 2499  Reuters (Media, https://www.reuters.com/articl...
# 2502  Ministry of Foreign Affairs — France (Governme...
#
# [63 rows x 5 columns]

# %% [markdown]
# ### Specific categories

# %%
[print(x) for x in source_data.loc[(source_data.CATEGORY=="Lockdown") & 
        (source_data.MEASURE=="Full lockdown"),"COMMENTS"]]
# Out:
# All production will be closed and strictly only those services remain open that are essential (e.g. pharmacies, health facilities, banks, grocery stores, ...)
# All regions at risk (specifically defined) need to implement a complete lock-down, including public services, schools, contract tracing, transport
# Full lock-down of the multiple regions with only essential services remaining and people allowed to leave their home for those; some include restrictions on leaving the municipality
# All of South Africa will go into total lockdown from the midight 26th March until 16th of April . This means individuals will not be allowed to leave their homes except for strict reasons (aside from essential workers in the response).
# Some villages
# The closure of all non-essential work, including private companies irrespective of health measures implemented as done for the rest of CH
# [None, None, None, None, None, None]

# %% [markdown]
# Full lockdown pretty unambiguously translates into 'blanket curfew - no symptoms'

# %%
res=[print(x) for x in source_data.loc[(source_data.CATEGORY=="Lockdown") & 
        (source_data.MEASURE=="Partial lockdown"),"COMMENTS"]]
# Out:
# Bilda (complete confinement - all movement in and out is prohibited) and Algiers
# Until 31st of March included, travels are restricted excepted for valid reasons and population is forced to quarantine. Limited quarantine exemptions include movement to obtain food and medical care and travel to the international airport for ticketed passengers only. Enforced by the police.
# Citizens are suspend all non-essential activities outside their homes and stay in their homes for the duration for one week; ecemptions are essential work, for essential shopping or services, helping someone else, physical activity if alone or with co-living persons
# All municipalities in Tyrol are under quarantine with no movements in between municipalities
# Police enforced general lock-down limiting the leaving of ones home only for emergencies, helping others and essential errands. Gathering and meetings are prohibited. Companies required to organize telework where possible, without exeption. Measures set to last until 5th April.
# Towns of Cotonou, Abomey-Calavi, Allada, Ouidah, Sèmè-Podji, Porto-Novo, Akpro-Missérété and Adjarra are under lockdown and isolated from the rest of the country by checkpoints.
# Discotheques, bars, movie theaters, sporting events, large gatherings, gyms, amusement parks, night-time activities at event halls are closed.
# All cinemas closed.
# School closures for one week starting Monday.
# Kindergartens, however, continue to operate.
# Closing of public places - galleries, cinemas, halls, all kinds of clubs (for children, pensioners, entertainment).
# Expanding the activities of social patronage with the possibility of delivering medicines and foodstuffs to the homes of elderly people.
# Closing of all periodic and temporary markets (Dolni Bogrov, Malashevtsi, etc.).
# Maximize the opportunities for remote work.
# Provision and organization of an awareness campaign and additional disinfection in Roma neighbourhoods.
# Extension of enhanced measures for disinfection of all spaces and institutions.
# Suspension of night public transport.It is planned that the evening and drinking establishments will be closed for two weeks, but the restaurants and fast food establishments will continue to work. NON COMPLIANCE: Offenders will face "sanctions"
# In many regions
# nightly curfew as of 16 March from 7pm until 6am in Córdoba, Meta and Santander Departments
# Nationwide quarantine from 16 March until 24 March, except for essential needs, helping others and necessary trips to famillies
# Stict confinement with a curfew from 9pm to 5am.
# The President of El Salvador implemented a 48-hour cordón sanitario for the entire municipality of Metapan following the first confirmed case of Covid-19.   Movement in and out of Metapan is restricted.
# The President of El Salvador declared a 30-day nationwide quarantine on Wednesday, March 11
# Closure of all non-essential establishments
# further restrictions of movement, all people requested to remain at home unless for essential purposes starting 17 March to last for 2 weeks
# quarantine order for Marneuli and Bolnisi, two neighboring municipalities one hour south of Tbilisi. Cargo and personal movement within the municipalities will continue, but no one will be allowed to enter or exit the areas.
# Freiburg started, with ongoing discussions on federal level, a partial lock-down
# Nation wide until further notice. People are only allowed to go out for essential work, health reasons, short walks or to acquire essential supplies. They must carry ID, and the reason for their movements has to be confirmed by their employer or by themselves. Those found violating the rules will receive a 150 euro on-the-spot fine.
# Citizens must stay at home and limit movement to essential only
# shops and restaurants (excluding food stores and pharmacies) must close at 3 p.m. due to the coronavirus epidemic does not apply to post offices. Post offices will receive customers during the opening hours stated at the entrance. It is important that this regulation does not yet apply to the services sector – such as nail parlors, hairdressers and gymnasiums – meaning that they may remain open beyond 3 p.m. At the same time, we strongly advise everyone to comply with disease control precautions.
# closure of selected public institutions such as museums (incl. Taj Mahal) until March 31 and postponement of several local elections
# lockdown for 7 days in Najaf governorate as of March 11
# mandatory lockdown: do not go outside unless absolutely necessary.
#  further reducing entry to the public space, imposing responsibility on employers, closing non-essential stores and imposing restrictions on public transport.
# social distancing, leave home only for specified reasons: getting to/from work, purchasing essential food, medicine, other essential products/services; medical treatment; blood donation; demonstration; legal processes; sports activity (alone or with members of same household); going out for short periods alone or with household only; going for religious ceremony (up to 10 people with 2 meters distance; going to provide assistance to someone with another medical problem/ needs support; essential purposes
# Northern Italian regions (NUTS2) officially locked down
# Limitations extended with public parks and playgrounds closing and more restrictions on being outside
# Nationally, the movement between municipalities is banned (apart for essential reasons)
# General lockdown across component of everyday life; businesses can continue if they implement safety measures
# Government imposes Defense law. All public and private offices shut down for two weeks.  Movement between cities and towns is stritcly prohibilited.  Military is deployed to enforce regulations
# Korean government will restrict the operation of some facilities, such as religious facilities, indoor sports, and entertainment facilities which are at high risk of infection.
# traffic is limited to essential trips only
# Leaving is allowed for essentials, to get fresh air and work (if home office is not applicable)
# Movement Control Order (MCO) in place from March 18-31 in place under the Prevention and Control of Infectious Diseases Act 1988 and the Police Act 1967. Government and private offices apart from those providing essential services are closed. All shops other than businesses dealing with daily essentials – such as food and pharmaceutical stores are closed. The Chief Minister of Sarawak has announced that people will only be allowed to leave their homes in order to buy daily necessities, essential goods and services.
# From 18 - 31 March 2020, Sarawakians entering the state are subject to the 14-day Stay Home Notice, issued by the State Department of Health and they are not allowed to travel out of Sarawak throughout the 14-day MCO period.
# All markets, supermarkets, coffee shops and restaurants in Sarawak can only open from 7am to 7pm starting Tuesday (March 24), says the state disaster management committee. Supermarkets, hypermarkets, markets, pharmacies and private clinics were now required to practise social distancing in their premises. "The police will check the implementation randomly,"
# nan
# nan
# New Zealanders who are outside of essential services must stay at home and stop all interactions with others outside of those in your households.
# Bethlehem in lockdown after cases confirmed
# 14 day national lockdown starting tomorrow March 24
# Forced quarantine, travels are regulated and limited.
# People are not allowed to leave their home, apart for essential matters, including any kind of work
# Announcement of lockdown for the country of Rwanda for a period of 2 weeks. Preventative measures for the next 2 weeks: non-essential movement outside the home is not permitted, all employees shall work from home except those providing essential services, non-essential shops and markets are closed, all bars are closed, and motos/restaurants/cafes may only provide take-away/delivery services.
# All persons of the age of 60 and above are to remain at home and must not move out and about in public, unless he or she is seeking medical attention at any health facility.
# lockdown in Makkah, Madinah and Riyadh – no residents are allowed to enter or leave these cities – with immediate effect from 25 March; as well as a lockdown on circulation between the kingdom’s 13 regions
# Movement only allowed for: travel to make essential purchases (food, hygiene, health, first necessity), in strict compliance with basic precautionary measures; travel to his place of work and return to his usual place of residence; travel to access banking services; travel to provide care and assistance to vulnerable people; travel in cases of force majeure.; fines from 100 to 600.000 EUR
# Reasons for leaving home are for groceries, health, help someone and work
# People above 65 are ordered to stay at home
# Lomé, Tsévié, Kpalimé et Sokodé under lockdown.
# General lockdown in UK of immediate effect. People are only permitted to leave home for 3 reasons: shoppig for basic necessities as infrequently as possible, one for of exercise a day (alone or with members of your household), any medical need, and travelling to and from work but only where this is absolutely necessary and cannot be done at home.
# 65+ are asked to remain at home.
# Aneityum Island and the small, adjoining Mystery Island, are now "under temporary lockdown" after a passenger reportedly infected while onboard the cruise ship, Voyager of the Seas, visited the island
# Partial quarantine expanded to entire country.
# All transports are limited to the strict minimum (i.e. buying food or medication)

# %% [markdown]
# Partial lockdown might in occasional circumstances be not quite a blanket curfew, but it generally is.
#
# Some exceptions: "All cinemas closed.", "shops and restaurants (excluding food stores and pharmacies) must close at 3 p.m. due to the coronavirus epidemic does not apply to post offices."
